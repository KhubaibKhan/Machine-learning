# %% [markdown]
# # Logistic Regression
#         Logistic Regression is used to predict descrete value output, like if you want to predict the digit from an image.
#         Logistic Regression is an example of Supervised learning because we have give it labeled data, then ask it to label the unlabled data.
# # Hypothesis:
#     We can use the hypothesis of linear regression for logistic which will fit a straight line that will classify the data but it will only work for simple data. Using the hypothesis of linear regression for Logistic regression is not a good idea.
# ## Logistic Regression Model:
#     In logistic regression we want the hypothesis to output a value between o  and 1.
# $$ 0 <= h_Q(x) <= 1 $$
#     For linear Regression we had.
# $$ h_Q(x) = Q^Tx $$
#     For Logistic Regression we will use a slightly modified version.
# $$ h_Q(x) = g(Q^Tx) $$
# where $$ g(z) = \frac{1}{1 + e^{-Q^Tx}} $$
# This function is known as Sigmoid or Logistic function. This is where Logistic Regression got its name from.

# %%
import numpy as np
x = np.linspace(-10, 10, 100)
def sigmoid(z):
    return 1 / (1 + np.exp(-z))
y = sigmoid(x)

# %% [markdown]
#     The sigmoid function will always gives value between 0 and 1.

# %% [markdown]
# ![title](image/sigmoid.png)

# %% [markdown]
# ## Logistic Regression Cost Function:
#      The cost function is difference between the original value and the predicted value. In linear regression we had used RMSE cost function. In logistic regression we will chose another cost function.
#      In losgistic regression we use different cost function because for logistic regression the linear regression cost is not convex which is very hard to minimize.
#
# $$ Cost(h_Q(x), y) = { {-\log(h_Q(x)) if y=0}......\&.......
# {-\log(1 - h_Q(x) if y=1}}$$
# * $Cost = 0$ if $y=1$ and $ h_Q(x)=1 $
# * $Cost = 0$ if $y=0$ and $ h_Q(x)=0 $
# * $Cost = \infty$ if $y=0$ and $ h_Q(x)=1 $ or if $y=1$ and $ h_Q(x)=0 $
#         The below graph prove the above points.

# %%
def cost(y_pred, y_true):
    cost = np.mean((y_true*np.log(y_pred) + (1 - y_true)*np.log(1 - y_pred)))*-1
    print(cost)
    return cost

# %%
from ipywidgets import *
import plotly.graph_objs as go
layout = go.Layout(
    title = "Cost of Logistic Regression",
    yaxis = dict(
        title = "Cost"
    ),
    xaxis = dict(
        title = "y_predicted"
    ),
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)'
)

x = []
y = []

def update_plot(y_predicted, y_true):
    data = []
    for y_t in y_true:
        x.append(y_predicted)
        y.append(cost(y_predicted, y_t))
        trace = go.Scatter(
            x = x,
            y = y,
            mode = "lines+markers",
            name = "Cost",
            marker = dict(
                color = 'red',
                size=5
            )
        )
    data.append(trace)
    fig = go.Figure(data = data, layout = layout)
    fig.update_xaxes(range=[0, 1])
    fig.update_yaxes(range=[0, 4])
    fig.show()
y_predicted = FloatSlider(min=0.001, max=1,step=0.001, value=0.1)
y_true = SelectMultiple(options=list(np.arange(2)), value=(0, ))
interactive_plot = interactive(update_plot, y_predicted=y_predicted, y_true=y_true)
interactive_plot.children[0].continuous_update = False
interactive_plot.children[1].continuous_update = False
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='y_predicted', max=1.0, min=…

# %% [markdown]
#  ### Hypothesis:
#
# \begin{align}
# \dot h_x & = g(z).....z = \theta_0 + \theta_1X
# \end{align}
# ### Parameter:
#
# $$ \theta_0 and \theta_1 $$
# ### Cost Function:
#
# $$ J(\theta) = -\frac{1}{m}[ \sum_{i=1}^{m}{y^{(i)}\log(h_Q(x^{(i)}))}
# {+(1 - y^{(i)})\log(1 - h_Q(x^{(i)})}]$$
#
# ### Goal:
#
# $$ Minimize  \ J(\theta_0, \theta_1)  using  \theta_0 and \theta_1 $$

# %% [markdown]
# ## Gradient Descent:
# Gradient descent is just an algorithm that minimize some arbitrary function $ \ J(\theta_0, \theta_1) $. There could be many $\theta $ not just two like $ J(\theta_0, \theta_1, \theta_2, \theta3, ....) $
# ### Outline:
# * Start with some $\theta_0 and \theta_1 $.
# * keep changing $\theta_0 and \theta_1 $ to reduce $ J(\theta_0, \theta_1)$ untill hopefully we endup at a minimum.
# ### Algorithm:
#     The algrithm of Gradient Desent.
# Repeat until convergence {
#
# $$ \theta_j := \theta_j - \alpha \frac{\mathrm{d}}{\mathrm{d}\theta_j}J(\theta_0, \theta_j) $$
# }
#
#
# $$ \theta_j := \theta_j - \alpha \frac{1}{m} \sum_{i=1}^{m} (h_\theta (x^{(i)}) - y^{(i)}) x^{i}_j $$
#
#     Now that we have the Hypothesis, cost function and gradient descent algorithm lets implement it using python from scratch.

# %%
class MyLogisticRegression():
    def __init__(self, no_of_attrs, alpha = 0.2, iteration=1000):
        self.alpha = alpha
        self.theta = np.random.rand(no_of_attrs)
        self.t_cost = []
        self.iter = iteration
        self.b = 0
    def fit(self, x_train, y_train):
        if len(self.theta) == 1:
            self.x = x_train.reshape(len(x_train), 1)
        else:
            self.x =  x_train
        for i in range(self.iter):
            Q_cost = self.cost(y_train)
            self.t_cost.append(Q_cost)
            self.GradientDescent(y_train)
            if i%1000 == 0:
                print(i, "Epoch completed with cost:", Q_cost, "theta", self.theta)
        print(10000, "Epoch completed with cost:", Q_cost, "theta", self.theta)
    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))
    def hypothesis(self, x_value):
        return self.sigmoid(np.dot(x_value, self.theta) + self.b)
    def cost(self, y_train):
        cost = np.mean((y_train*np.log(self.hypothesis(self.x)) + (1 - y_train)*np.log(1 - self.hypothesis(self.x))))*-1
        return cost
    def cost_der(self, y_given):
        cost = (self.hypothesis(self.x) - y_given)
        cost0 = cost
        cost = cost*self.x.T
        cost = np.mean(cost)
        cost0 = np.mean(cost0)
        return (cost0, cost)
    def GradientDescent(self, y_given):
        (gr0, gr1) = self.cost_der(y_given)
        self.theta = self.theta - self.alpha*gr1
        self.b = self.b - gr0
        
    def predict(self, x_test):
        return np.round(self.sigmoid(np.dot(x_test.reshape(len(x_test), len(self.theta)), self.theta) + b))
    def weights(self):
        return (self.theta, self.b)

# %%
x_train = np.array([[1, 2], [2, 3], [3, 4], [5, 6], [6, 7], [7, 8]])
y_train = np.array([1, 1, 1, 0, 0, 0])
log_reg = MyLogisticRegression(no_of_attrs = 2, iteration=10000)
log_reg.fit(x_train, y_train)
# Out:
# 0 Epoch completed with cost: 3.864605747858979 theta [-0.34478067  0.20517378]
# 1000 Epoch completed with cost: 0.018279626862423768 theta [-1.7530841  -1.20312965]
# 2000 Epoch completed with cost: 0.009943597214205206 theta [-2.04973554 -1.49978109]
# 3000 Epoch completed with cost: 0.0068662305011210414 theta [-2.23212871 -1.68217426]
# 4000 Epoch completed with cost: 0.005252392911722619 theta [-2.36467203 -1.81471758]
# 5000 Epoch completed with cost: 0.00425602744734617 theta [-2.46897742 -1.91902298]
# 6000 Epoch completed with cost: 0.0035788417805081925 theta [-2.55504013 -2.00508569]
# 7000 Epoch completed with cost: 0.0030883111010684516 theta [-2.62832552 -2.07837108]
# 8000 Epoch completed with cost: 0.0027164584818512544 theta [-2.69215457 -2.14220013]
# 9000 Epoch completed with cost: 0.0024247844377010028 theta [-2.74869863 -2.19874418]
# 10000 Epoch completed with cost: 0.002190049110325613 theta [-2.79940797 -2.24945352]

# %%
x = np.arange(100)
fig = go.Figure(
    data=[go.Scatter(x=x[:3], y=log_reg.t_cost[:3],
                     mode="lines",
                     line=dict(width=2, color="blue"))],
    layout=go.Layout(
        xaxis=dict(range=[0, 100], autorange=False, zeroline=False),
        yaxis=dict(range=[0, 2], autorange=False, zeroline=False),
        title_text="The cost of the model per iteration", hovermode="closest",
        updatemenus=[dict(type="buttons",
                          buttons=[dict(label="Play",
                                        method="animate",
                                        args=[None])])]),
      frames=[go.Frame(
        data=[go.Scatter(
            x=x[:k],
            y=log_reg.t_cost[:k],
            mode="lines",
            line=dict(color="red", width=2))
        ]) for k in range(3, 100)]
)

fig.show()
# Out:
# <div>
#
#
#             <div id="2792a7b3-6dcf-4929-8ebe-6edc5c192a52" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2792a7b3-6dcf-4929-8ebe-6edc5c192a52")) {
#                     Plotly.newPlot(
#                         '2792a7b3-6dcf-4929-8ebe-6edc5c192a52',
#                         [{"line": {"color": "blue", "width": 2}, "mode": "lines", "type": "scatter", "x": [0, 1, 2], "y": [3.864605747858979, 0.6455901287359703, 0.6127799196725673]}],
# ...

# %% [markdown]
# ### Making sure the model is working fine:
# * If $\ J(\theta)$ is not converging it means gradient descent is not working. Try changing the $\alpha$.
# * If $\alpha$ is too small, gradient descent can be slow to converge.
# * I $\alpha$ is too large $\ J(\theta)$ may not decrease and the model will not converge.
# * Chose alpha between $ 0.001 and 0.3$. It depends on the problem mostly.

# %%
trace = go.Scatter(
    x = x_train[:, 0],
    y = x_train[:, 1],
    mode = "markers",
    marker = dict(
        color = y_train,
        size = 20
    ),
    name = "points"
)
(w, b) = log_reg.weights()
x = np.arange(9)
y = -((w[0])/(w[1])*x + (b/w[1]))
trace1 = go.Scatter(
    x = x,
    y = y,
    mode = "lines",
    marker = dict(
        color = 'red'
    ),
    name = "separation boundry"
)

data = [trace, trace1]
layout = go.Layout(
    title = "Points with their labels",
    paper_bgcolor='rgba(1,1,1,0.5)',
    plot_bgcolor='rgba(0,0,0,0)'
)
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="d3e4ce47-cff7-4e71-ac70-39d6c3382cfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d3e4ce47-cff7-4e71-ac70-39d6c3382cfb")) {
#                     Plotly.newPlot(
#                         'd3e4ce47-cff7-4e71-ac70-39d6c3382cfb',
# ...

# %% [markdown]
#     The above graph show the separation line.

# %%
log_reg.predict(np.array([[0, 10]]))
# Out:
# array([0.])

# %% [markdown]
#     The model is working fine because as the predicted data show. This is just a demonstration the real life will not be that simple and we will not always be able to separate them visualy.

# %% [markdown]
# ## Logistic Regression using scikit-learn:
#     We can implement the logistic regression using a few lines of code.
#     We will classify the flower data which is already present in sklearn.

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
x, y = load_iris(return_X_y=True)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
log_reg = LogisticRegression(random_state=0,solver='lbfgs', multi_class='multinomial', max_iter=100).fit(x_train, y_train)

# %%
log_reg.score(x_test, y_test)
# Out:
# 0.98

# %% [markdown]
#     The model gives about 98% accuracy on the test set so it is working fine.

# %%
log_reg.get_params(deep=True)
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'multinomial',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 0,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ## Logistic Regression using Tensorflow:

# %%
import tensorflow as tf

# %%
NUM_STEPS = 1000

x_data = np.array([[1, 2], [2, 3], [3, 4], [5, 6], [6, 7], [7, 8]])
y_data = np.array([1, 1, 1, 0, 0, 0])
#y_data = y_data_pre_noise + y_data
wb_ = []
loss_ = []

print(np.shape(x_data))

g = tf.Graph()
with g.as_default():
    x = tf.placeholder(tf.float32)
    y_true = tf.placeholder(tf.float32)
    with tf.name_scope('inference') as scope:
        w = tf.Variable([[0, 0]], dtype=tf.float32, name='weights')
        b = tf.Variable(0, dtype=tf.float32, name='bias')
        y_pred = tf.matmul(w, tf.transpose(x)) + b
    with tf.name_scope('loss') as scope:
        loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=y_true, logits=y_pred)
        loss = tf.reduce_mean(loss)
    with tf.name_scope('train') as scope:
        learning_rate = 0.1
        optimizer = tf.train.GradientDescentOptimizer(learning_rate)
        train = optimizer.minimize(loss)
    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        for step in range(NUM_STEPS):
            sess.run(train, {x:x_data, y_true:y_data})
            if step%100 == 0:
                print(step, sess.run([w, b]), sess.run(loss, {x:x_data, y_true:y_data}))
                wb_.append(sess.run([w, b]))
            loss_.append(sess.run(loss, {x:x_data, y_true:y_data}))
        print(1000, sess.run([w, b]), sess.run(loss, {x:x_data, y_true:y_data}))
# Out:
# (6, 2)
# 0 [array([[-0.1, -0.1]], dtype=float32), -1.4901161e-09] 0.6102293
# 100 [array([[-0.95410097,  0.3852628 ]], dtype=float32), 1.3393632] 0.32525757
# 200 [array([[-1.4810586,  0.6626548]], dtype=float32), 2.1437123] 0.22387783
# 300 [array([[-1.8535864,  0.856473 ]], dtype=float32), 2.710058] 0.17388873
# 400 [array([[-2.1428263,  1.0059873]], dtype=float32), 3.1488125] 0.14394845
# 500 [array([[-2.3804476,  1.128291 ]], dtype=float32), 3.508739] 0.123817235
# 600 [array([[-2.5829532,  1.2321925]], dtype=float32), 3.815147] 0.10923293
# 700 [array([[-2.7599788,  1.3227988]], dtype=float32), 4.0827785] 0.09810808
# 800 [array([[-2.9176285,  1.4033289]], dtype=float32), 4.3209567] 0.089297436
# 900 [array([[-3.0600188,  1.475945 ]], dtype=float32), 4.5359626] 0.08211779
# 1000 [array([[-3.188809 ,  1.5415349]], dtype=float32), 4.730343] 0.07619024

# %%
trace = go.Scatter(
    x = np.arange(1000),
    y = loss_,
    mode = 'lines',
    marker = dict(
        color = 'red'
    )
)
layout = go.Layout(
    title = "Cost per iteration",
    titlefont = dict(
        color = "rgba(200, 200, 200, 200)"
    ),
    xaxis = dict(
        title = "No of iteration",
        color = "rgba(200, 200, 200, 200)"
    ),
    yaxis = dict(
        title = "Loss",
        color = "rgba(200, 200, 200, 200)"
    ),
    paper_bgcolor='rgba(1,1,1,0.5)',
    plot_bgcolor='rgba(0,0,0,0)'
)

fig = go.Figure(data = trace, layout = layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="e6906c91-ac29-4b30-ae55-1e813b94b600" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e6906c91-ac29-4b30-ae55-1e813b94b600")) {
#                     Plotly.newPlot(
#                         'e6906c91-ac29-4b30-ae55-1e813b94b600',
# ...

# %%
trace = go.Scatter(
    x = x_data[:, 0],
    y = x_data[:, 1],
    mode = "markers",
    marker = dict(
        color = y_data,
        size = 20
    ),
    name = "points"
)
(w, b) = wb_[-1]
x = np.arange(9)
y = -((w[0][0])/(w[0][1])*x + (b/w[0][1]))
trace1 = go.Scatter(
    x = x,
    y = y,
    mode = "lines",
    marker = dict(
        color = 'red'
    ),
    name = "separation boundry"
)

data = [trace, trace1]
layout = go.Layout(
    title = "Points with their labels",
    paper_bgcolor='rgba(1,1,1,0.5)',
    plot_bgcolor='rgba(0,0,0,0)'
)
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="cd0e9e43-ac22-4248-8c0a-567e7785724f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd0e9e43-ac22-4248-8c0a-567e7785724f")) {
#                     Plotly.newPlot(
#                         'cd0e9e43-ac22-4248-8c0a-567e7785724f',
# ...

# %% [markdown]
#     The above graph show the separation line which separate the two classes.
